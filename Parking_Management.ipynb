-- %% [markdown]
-- # [dbo].[CarsTb1]

-- %%
USE [ParkingManagementSytem]
GO

-- %%
/****** Object:  Table [dbo].[CarsTb1]    Script Date: 16/01/2024 18:40:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CarsTb1](
	[CNum] [int] IDENTITY(1,1) NOT NULL,
	[PNumber] [varchar](50) NOT NULL,
	[Driver] [varchar](50) NOT NULL,
	[Gender] [varchar](50) NOT NULL,
	[CarType] [varchar](50) NOT NULL,
	[CarColor] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[CNum] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ParkingTb1]

-- %%
/****** Object:  Table [dbo].[ParkingTb1]    Script Date: 16/01/2024 18:40:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ParkingTb1](
	[PCode] [int] IDENTITY(1,1) NOT NULL,
	[Car] [int] NOT NULL,
	[Datee] [date] NULL,
	[Duration] [int] NOT NULL,
	[Amount] [int] NOT NULL,
	[Place] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[PCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlaceTb1]

-- %%
/****** Object:  Table [dbo].[PlaceTb1]    Script Date: 16/01/2024 18:40:40 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlaceTb1](
	[PlNum] [int] IDENTITY(1,1) NOT NULL,
	[Ppositioh] [varchar](150) NOT NULL,
	[PStatus] [varchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[PlNum] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK1]

-- %%
ALTER TABLE [dbo].[ParkingTb1]  WITH CHECK ADD  CONSTRAINT [FK1] FOREIGN KEY([Car])
REFERENCES [dbo].[CarsTb1] ([CNum])
GO
ALTER TABLE [dbo].[ParkingTb1] CHECK CONSTRAINT [FK1]
GO

-- %% [markdown]
-- # [FK2]

-- %%
ALTER TABLE [dbo].[ParkingTb1]  WITH CHECK ADD  CONSTRAINT [FK2] FOREIGN KEY([Place])
REFERENCES [dbo].[PlaceTb1] ([PlNum])
GO
ALTER TABLE [dbo].[ParkingTb1] CHECK CONSTRAINT [FK2]
GO
